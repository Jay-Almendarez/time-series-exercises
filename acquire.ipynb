# %%
import requests
import pandas as pd
from acquire import df_from_api

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Using the code from the lesson as a guide and the REST API from https://swapi.dev/ as we did in the lesson, create a dataframe named people that has all of the data for people.

# %% [markdown]
# def df_from_api(criteria):
#     response = requests.get(f'https://swapi.dev/api/{criteria}/')
#     df_name = response.json()
#     num = range(2, df_name['count']+1)
#     count = df_name['count']
#     response = requests.get(f'https://swapi.dev/api/{criteria}/1/')
#     df_name = response.json()
#     df_name = pd.Series(df_name)
#     df_name = pd.DataFrame(df_name).T
#     for i in num:
#         response = requests.get(f'https://swapi.dev/api/{criteria}/{i}/')
#         df_name_new = response.json()
#         df_name_new = pd.Series(df_name_new)
#         df_name_new = pd.DataFrame(df_name_new).T
#         df_name = pd.concat([df_name, df_name_new], axis=0, ignore_index=True)
#     return df_name

# %%
people = df_from_api('people')
people
# Out:
#                name height mass hair_color        skin_color      eye_color  \
# 0    Luke Skywalker    172   77      blond              fair           blue
# 1             C-3PO    167   75        n/a              gold         yellow
# 2             R2-D2     96   32        n/a       white, blue            red
# 3       Darth Vader    202  136       none             white         yellow
# 4       Leia Organa    150   49      brown             light          brown
# ..              ...    ...  ...        ...               ...            ...
# 77         Shaak Ti    178   57       none  red, blue, white          black
# 78         Grievous    216  159       none      brown, white  green, yellow
# 79          Tarfful    234  136      brown             brown           blue
# 80  Raymus Antilles    188   79      brown             light          brown
# 81        Sly Moore    178   48       none              pale          white
#
# ...

# %% [markdown]
# ## Do the same thing, but for planets.

# %%
planets = df_from_api('planets')
planets
# Out:
#               name rotation_period orbital_period diameter  \
# 0         Tatooine              23            304    10465
# 1         Alderaan              24            364    12500
# 2         Yavin IV              24           4818    10200
# 3             Hoth              23            549     7200
# 4          Dagobah              23            341     8900
# 5           Bespin              12           5110   118000
# 6            Endor              18            402     4900
# 7            Naboo              26            312    12120
# 8        Coruscant              24            368    12240
# 9           Kamino              27            463    19720
# 10        Geonosis              30            256    11370
# 11          Utapau              27            351    12900
# 12        Mustafar              36            412     4200
# 13        Kashyyyk              26            381    12765
# 14     Polis Massa              24            590        0
# ...

# %% [markdown]
# ## Extract the data for starships.

# %%
starships = df_from_api('starships')
starships
# Out:
#        detail                           name  \
# 0   Not found                            NaN
# 1         NaN                  CR90 corvette
# 2         NaN                 Star Destroyer
# 3   Not found                            NaN
# 4         NaN   Sentinel-class landing craft
# 5   Not found                            NaN
# 6   Not found                            NaN
# 7   Not found                            NaN
# 8         NaN                     Death Star
# 9         NaN              Millennium Falcon
# 10        NaN                         Y-wing
# 11        NaN                         X-wing
# 12        NaN                TIE Advanced x1
# 13  Not found                            NaN
# 14        NaN                       Executor
# 15  Not found                            NaN
# 16        NaN                Rebel transport
# 17  Not found                            NaN
# 18  Not found                            NaN
# 19  Not found                            NaN
# ...

# %%
starships = starships.drop(columns='detail')
starships
# Out:
#                              name                                 model  \
# 0                             NaN                                   NaN
# 1                   CR90 corvette                         CR90 corvette
# 2                  Star Destroyer       Imperial I-class Star Destroyer
# 3                             NaN                                   NaN
# 4    Sentinel-class landing craft          Sentinel-class landing craft
# 5                             NaN                                   NaN
# 6                             NaN                                   NaN
# 7                             NaN                                   NaN
# 8                      Death Star           DS-1 Orbital Battle Station
# 9               Millennium Falcon               YT-1300 light freighter
# 10                         Y-wing                            BTL Y-wing
# 11                         X-wing                           T-65 X-wing
# ...

# %% [markdown]
# ## Save the df_from_api your files to local csv files so that it will be faster to access in the future.

# %% [markdown]
# Done.
#
# people.to_csv('swapi_people.csv')
#
# planets.to_csv('swapi_planets.csv')
#
# starships.to_csv('swapi_starships.csv')

# %% [markdown]
# ## Combine the data from your three separate dataframes into one large dataframe.

# %%
people = pd.read_csv('swapi_people.csv')
planets = pd.read_csv('swapi_planets.csv')
starships = pd.read_csv('swapi_starships.csv')

# %%
people.columns
# Out:
# Index(['Unnamed: 0', 'name', 'height', 'mass', 'hair_color', 'skin_color',
#        'eye_color', 'birth_year', 'gender', 'homeworld', 'films', 'species',
#        'vehicles', 'starships', 'created', 'edited', 'url', 'detail'],
#       dtype='object')

# %%
planets.columns
# Out:
# Index(['Unnamed: 0', 'name', 'rotation_period', 'orbital_period', 'diameter',
#        'climate', 'gravity', 'terrain', 'surface_water', 'population',
#        'residents', 'films', 'created', 'edited', 'url'],
#       dtype='object')

# %%
starships.columns
# Out:
# Index(['Unnamed: 0', 'name', 'model', 'manufacturer', 'cost_in_credits',
#        'length', 'max_atmosphering_speed', 'crew', 'passengers',
#        'cargo_capacity', 'consumables', 'hyperdrive_rating', 'MGLT',
#        'starship_class', 'pilots', 'films', 'created', 'edited', 'url'],
#       dtype='object')

# %%
people_planet = people.merge(planets, left_on='homeworld', right_on='url', how= 'left', suffixes=['_people', '_planet'])
# Out:
#     Unnamed: 0_people      name_people height mass hair_color  \
# 0                   0   Luke Skywalker    172   77      blond
# 1                   1            C-3PO    167   75        NaN
# 2                   2            R2-D2     96   32        NaN
# 3                   3      Darth Vader    202  136       none
# 4                   4      Leia Organa    150   49      brown
# ..                ...              ...    ...  ...        ...
# 77                 77         Shaak Ti    178   57       none
# 78                 78         Grievous    216  159       none
# 79                 79          Tarfful    234  136      brown
# 80                 80  Raymus Antilles    188   79      brown
# 81                 81        Sly Moore    178   48       none
#
#           skin_color      eye_color birth_year  gender  \
# 0               fair           blue      19BBY    male
# 1               gold         yellow     112BBY     NaN
# ...

# %%
far_far_away = pd.concat([people, planets, starships], axis=0, ignore_index=True)
far_far_away
# Out:
#      Unnamed: 0                name height mass hair_color   skin_color  \
# 0             0      Luke Skywalker    172   77      blond         fair
# 1             1               C-3PO    167   75        NaN         gold
# 2             2               R2-D2     96   32        NaN  white, blue
# 3             3         Darth Vader    202  136       none        white
# 4             4         Leia Organa    150   49      brown        light
# ..          ...                 ...    ...  ...        ...          ...
# 173          31  Droid control ship    NaN  NaN        NaN          NaN
# 174          32                 NaN    NaN  NaN        NaN          NaN
# 175          33                 NaN    NaN  NaN        NaN          NaN
# 176          34                 NaN    NaN  NaN        NaN          NaN
# 177          35                 NaN    NaN  NaN        NaN          NaN
#
#     eye_color birth_year  gender                         homeworld  ...  \
# ...

# %% [markdown]
# ## Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv

# %%
opsd = pd.read_csv('opsd.csv')
opsd.sample(5)
# Out:
#             Date  Consumption     Wind    Solar  Wind+Solar
# 3352  2015-03-07     1317.425  269.203  114.556     383.759
# 3805  2016-06-02     1421.839  108.363  120.895     229.258
# 3470  2015-07-03     1439.366   71.633  189.467     261.100
# 2852  2013-10-23     1425.148  285.689   31.867     317.556
# 1702  2010-08-30     1328.642  114.569      NaN         NaN

# %% [markdown]
# ## Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions in the acquire.py file and be able to re-run the functions and get the same data.

# %% [markdown]
# Done.
